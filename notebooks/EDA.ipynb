# %%
#Load all environments
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import streamlit as st
# Read the dataset’s CSV file into a Pandas DataFrame
cars_df = pd.read_csv('vehicles_us.csv')

# %%
# Display basic information about the dataset
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
# Display summary statistics
cars_df.describe()
# Out:
#                price    model_year     cylinders       odometer   is_4wd  \
# count   51525.000000  47906.000000  46265.000000   43633.000000  25572.0
# mean    12132.464920   2009.750470      6.125235  115553.461738      1.0
# std     10040.803015      6.282065      1.660360   65094.611341      0.0
# min         1.000000   1908.000000      3.000000       0.000000      1.0
# 25%      5000.000000   2006.000000      4.000000   70000.000000      1.0
# 50%      9000.000000   2011.000000      6.000000  113000.000000      1.0
# 75%     16839.000000   2014.000000      8.000000  155000.000000      1.0
# max    375000.000000   2019.000000     12.000000  990000.000000      1.0
#
#        days_listed
# count  51525.00000
# mean      39.55476
# std       28.20427
# min        0.00000
# 25%       19.00000
# 50%       33.00000
# 75%       53.00000
# max      271.00000

# %%
# Check for missing values
cars_df.isnull().sum()
# Out:
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# dtype: int64

# %%
# Remove missing values 
cars_df.dropna(inplace=True)
# Check for missing values agin
cars_df.isnull().sum()
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %%
# Plot histogram of prices
plt.hist(cars_df['price'], bins=50)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Distribution')
plt.show()

# %%
# Convert model_year to integer cars_df['model_year'] = cars_df['model_year'].astype(int) # Scatter Plot of Price by Car Type plt.figure(figsize=(12, 6)) sns.scatterplot(x='type', y='price', data=cars_df) plt.xlabel('Car Type') plt.ylabel('Price') plt.title('Price by Car Type') plt.xticks(rotation=45) plt.show()# Plot scatter plot of price vs. model year
sns.scatterplot(x='model_year', y='price', data=cars_df)
plt.xlabel('Model Year')
plt.ylabel('Price')
plt.title('Price vs. Model Year')
plt.show()

# %%
# Convert model_year to integer 
cars_df['model_year'] = cars_df['model_year'].astype(int) 
# Scatter Plot of Price by Car Type 
plt.figure(figsize=(12, 6)) 
sns.scatterplot(x='type', y='price', data=cars_df) 
plt.xlabel('Car_Type') 
plt.ylabel('Price') 
plt.title('Price by Car Type') 
plt.xticks(rotation=45) 
plt.show()
